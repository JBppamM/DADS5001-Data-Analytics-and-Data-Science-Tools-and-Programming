# %% [markdown]
# <a href="https://colab.research.google.com/github/JBppamM/DADS5001-Data-Analytics-and-Data-Science-Tools-and-Programming/blob/main/01_Data_Sources/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Youtube

# %%
# !pip install pytchat #https://github.com/taizan-hokuto/pytchat/wiki
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import pytchat
chat = pytchat.create(video_id="xW-hj937DkI")

while chat.is_alive():
  for c in chat.get().sync_items():
    #print(dir(c))
    print(f"{c.datetime} [{c.author.name}]- {c.message}")
# Out:
# 2026-01-15 23:01:33 [@โด้อ้วน-ง2จ]- :thumbs_up:
# 2026-01-15 23:01:38 [@boybank2499]- :hand-pink-waving::hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:01:46 [@nichapathyangyuen848]- :hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:01:47 [@boybank2499]- สวัสดีครับ
# 2026-01-15 23:01:50 [@AUTimmy]- เวรกรรมประเทศนี้
# 2026-01-15 23:01:50 [@omg-fu1zb]- :folded_hands::light_blue_heart::light_blue_heart::light_blue_heart:
# 2026-01-15 23:01:53 [@โด้อ้วน-ง2จ]- :face_with_tears_of_joy:
# 2026-01-15 23:02:00 [@เพ็ญณีเนาวราช]- :hand-pink-waving::hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:02:02 [@omg-fu1zb]- :face-red-heart-shape:
# 2026-01-15 23:02:02 [@G-AlligatorRaptorT-Rex]- :hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:02:06 [@มะลิวรรณจันทา-ย1ข]- :cat-orange-whistling::cat-orange-whistling::cat-orange-whistling::cat-orange-whistling:
# 2026-01-15 23:02:11 [@รัดจันทร์โพธิ์ศรี]- สวัสดีค่ะ
# 2026-01-15 23:02:12 [@artsumaauzmar2081]- ทำไรคนคนตื่นเช้า
# ...

# %%
import pytchat
import pandas as pd
chat = pytchat.create(video_id="xW-hj937DkI")

dList = []
aList = []
mList = []

i = 0
while chat.is_alive():
  for c in chat.get().sync_items():
    print(f"{c.datetime} [{c.author.name}]- {c.message}")
    dList.append(c.datetime)
    aList.append(c.author.name)
    mList.append(c.message)
    i = i+1
    if i == 10:
      chat.terminate()
      break

# dictionary of lists
dict = {'dateTime': dList, 'authorName': aList, 'Message': mList}

df = pd.DataFrame(dict)
df.head()

from google.colab import files
df.to_csv("data.csv", encoding="utf_8_sig", index=False) #cp874, #TIS-620
files.download("data.csv")
# Out:
# 2026-01-15 23:01:33 [@โด้อ้วน-ง2จ]- :thumbs_up:
# 2026-01-15 23:01:38 [@boybank2499]- :hand-pink-waving::hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:01:46 [@nichapathyangyuen848]- :hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:01:47 [@boybank2499]- สวัสดีครับ
# 2026-01-15 23:01:50 [@AUTimmy]- เวรกรรมประเทศนี้
# 2026-01-15 23:01:50 [@omg-fu1zb]- :folded_hands::light_blue_heart::light_blue_heart::light_blue_heart:
# 2026-01-15 23:01:53 [@โด้อ้วน-ง2จ]- :face_with_tears_of_joy:
# 2026-01-15 23:02:00 [@เพ็ญณีเนาวราช]- :hand-pink-waving::hand-pink-waving::hand-pink-waving:
# 2026-01-15 23:02:02 [@omg-fu1zb]- :face-red-heart-shape:
# 2026-01-15 23:02:02 [@G-AlligatorRaptorT-Rex]- :hand-pink-waving::hand-pink-waving:

# %% [markdown]
# # Web scrape (https://playwright.dev/)

# %% [markdown]
# ## Install libraries

# %%
# !apt-get update
# !apt-get install -y libatk1.0-0 libxcomposite1 libgtk-3-0 libgstreamer-plugins-base1.0-0 libgstreamer1.0-0 gstreamer1.0-plugins-base gstreamer1.0-plugins-good libgstreamer-gl1.0-0 libgstreamer-plugins-bad1.0-0 libavif13 libharfbuzz-icu0 libmanette-0.2-0 libenchant-2-2 libhyphen0 libsecret-1-0
# !pip install playwright
# !python -m playwright install
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [107 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.7 MB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# ...

# %%
from playwright.async_api import async_playwright
import asyncio

async def scrape_data():
    async with async_playwright() as p:
        # Launch browser (set headless=False to watch visually)
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Navigate to target page
        await page.goto("https://books.toscrape.com/")

        # Extract main header text
        title = await page.locator("h1").inner_text()
        print(f"Page Title: {title}")

        # Extract multiple items
        books = page.locator("article.product_pod")
        count = await books.count()

        for i in range(count):
            book = books.nth(i)
            name = await book.locator("h3 a").get_attribute("title")
            price = await book.locator(".price_color").inner_text()
            print(f"{name} - {price}")

        await browser.close()

# Run the async function
await scrape_data()
# Out:
# Page Title: All products
# A Light in the Attic - £51.77
# Tipping the Velvet - £53.74
# Soumission - £50.10
# Sharp Objects - £47.82
# Sapiens: A Brief History of Humankind - £54.23
# The Requiem Red - £22.65
# The Dirty Little Secrets of Getting Your Dream Job - £33.34
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull - £17.93
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics - £22.60
# The Black Maria - £52.15
# Starving Hearts (Triangular Trade Trilogy, #1) - £13.99
# Shakespeare's Sonnets - £20.66
# Set Me Free - £17.46
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) - £52.29
# Rip it Up and Start Again - £35.02
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 - £57.25
# Olio - £23.88
# Mesaerion: The Best Science Fiction Stories 1800-1849 - £37.59
# Libertarianism for Beginners - £51.33
# It's Only the Himalayas - £45.17

# %% [markdown]
# #Exercise
# ## - Collect gold price (ราคารับซื้อ ทองคำแท่ง) from https://www.goldtraders.or.th/

# %%
from playwright.async_api import async_playwright
import asyncio
import json
import pandas as pd

async def scrape_data():
    async with async_playwright() as p:
        # Launch browser (set headless=False to watch visually)
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Navigate to target page
        await page.goto("https://www.goldtraders.or.th/")

        # Extract main header text
        title = await page.locator("h1").inner_text()
        subtitle = await page.locator('[data-slot="select-value"]').inner_text()
        print(f"Page Title: {title}")
        print(subtitle)

        G_Type_loc    = page.locator(".text-xl.font-bold")
        G_price_loc     = page.locator(".text-lg.font-bold")
        count = await G_Type_loc.count()
        # print(range(count))
        # print(type(range(count)))
        datalist=[]
        for i in range(count):
          Gold_Type = await G_Type_loc.nth(i).inner_text()
          Gold_price = await G_price_loc.nth(i).inner_text()

          if "ทอง" in Gold_Type:
            print(f"{Gold_Type} : {Gold_price}")
            # datalist.append({"Name":Gold_Type,"Value":Gold_price})
          else:
            print(f"{Gold_price} : {Gold_Type}")
            # datalist.append({"Name":Gold_price,"Value":Gold_Type})
        await browser.close()

        # with open("Gold.json", "w", encoding="utf-8") as f:
        #   json.dump(datalist, f, ensure_ascii=False, indent=4)
        # print("json success")

        # df = pd.DataFrame(datalist)
        # df.to_excel("Gold.xlsx", index=False)



# Run the async function
await scrape_data()
# Out:
# Page Title: ราคาทองตามประกาศสมาคมค้าทองคำ
# ประจำวันที่ 14/08/2569 เวลา 17:20 (ครั้งที่ 20)
# ทองคำแท่ง : 96.5%
# รับซื้อ : 68,150.00
# ขายออก : 68,350.00
# ทองรูปพรรณ : 96.5%
# ฐานภาษี : 66,779.80
# ขายออก : 69,150.00

# %%
# <h1 class="text-center text-2xl leading-tight font-semibold md:text-4xl">ราคาทองตามประกาศ<span class="text-primary max-md:block">สมาคมค้าทองคำ</span></h1>
# <span data-slot="select-value" style="pointer-events: none;">ประจำวันที่ 09/08/2569 เวลา 15:14 (ครั้งที่ 2)</span>

# <span class="text-xl font-bold md:text-2xl">ทองคำแท่ง</span>
# <span class="text-lg font-bold">96.5%</span>


# <span class="text-primary text-lg font-bold">รับซื้อ</span>
# <span class="text-xl md:text-3xl font-bold text-green-600">67,700.00</span>

# <span class="text-primary text-lg font-bold">ขายออก</span>
# <span class="text-xl md:text-3xl font-bold text-green-600">67,900.00</span>

# <span class="text-xl font-bold md:text-2xl">ทองรูปพรรณ</span>
# <span class="text-lg font-bold">96.5%</span>

# <span class="text-primary text-lg font-bold">ฐานภาษี</span>
# <span class="text-xl md:text-3xl font-bold text-green-600">66,340.16</span>

# <span class="text-primary text-lg font-bold">ขายออก</span>
# <span class="text-xl md:text-3xl font-bold text-green-600">68,700.00</span>

# text-xl.font-bold => 0-6
# text-lg.font-bold => 0-6

# text-primary.text-lg.font-bold
# text-xl.md:text-3xl

# %% [markdown]
# #Exercise
#
# ## - Collect a number of goals from https://www.premierleague.com/en/stats/all-time

# %%
from playwright.async_api import async_playwright
import asyncio

async def scrape_data():
    async with async_playwright() as p:
        # Launch browser (set headless=False to watch visually)
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Navigate to target page
        await page.goto("https://www.premierleague.com/en/stats/all-time")

        # Extract main header text
        title = await page.locator('[data-testid="widgetHeaderTitle"]').nth(0).inner_text()
        print(f"Page Title: {title}")
        sub_title = await page.locator('.stats-leaderboard__header').nth(1).inner_text()
        print(sub_title)

        player_name_loc = page.locator('.stats-leaderboard__name')
        goals_score_loc = page.locator('.stats-leaderboard__stat-value')


        for i in range(10,20):
          player_name = await player_name_loc.nth(i).inner_text()
          goals_score = await goals_score_loc.nth(i).inner_text()

          print(f"Player Name : {player_name}, Goals score : {goals_score}")


        await browser.close()


# Run the async function
await scrape_data()
# Out:
# Page Title: All-time Premier League player stats
# Goals
# Player Name : Alan Shearer, Goals score : 260
# Player Name : Harry Kane, Goals score : 213
# Player Name : Wayne Rooney, Goals score : 208
# Player Name : Mohamed Salah, Goals score : 193
# Player Name : Andrew Cole, Goals score : 187
# Player Name : Sergio Agüero, Goals score : 184
# Player Name : Frank Lampard, Goals score : 177
# Player Name : Thierry Henry, Goals score : 175
# Player Name : Robbie Fowler, Goals score : 163
# Player Name : Jermain Defoe, Goals score : 162

# %%
# <h2 data-testid="widgetHeaderTitle" class="widget-header__title">All-time Premier League player stats</h2>
# <span class="stats-leaderboard__header">Goals</span>
# <span class="stats-leaderboard__name">Alan Shearer</span>
# <span class="stats-leaderboard__stat-value">260</span>
